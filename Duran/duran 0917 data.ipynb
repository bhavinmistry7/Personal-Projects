# %%
import re
import json
import requests

from bs4 import BeautifulSoup
import pandas as pd

# %%
url = 'https://understat.com/player/11366'

# %%
response = requests.get(url)
print(response.status_code)
# Out:
# 200

# %%
soup = BeautifulSoup(response.content, 'html.parser')
ugly_soup = str(soup)

# %%
shots_data = re.search("var shotsData .*= JSON.parse\('(.*)'\)", ugly_soup).group(1)

# %%
shots_data[:100]
# Out:
# '\\x5B\\x7B\\x22id\\x22\\x3A\\x22509044\\x22,\\x22minute\\x22\\x3A\\x2278\\x22,\\x22result\\x22\\x3A\\x22BlockedShot\\'

# %%
data = shots_data.encode('utf8').decode('unicode_escape')

# %%
data[:100]
# Out:
# '[{"id":"509044","minute":"78","result":"BlockedShot","X":"0.6919999694824219","Y":"0.599000015258789'

# %%
data = json.loads(data)

# %%
data
# Out:
# [{'id': '509044',
#   'minute': '78',
#   'result': 'BlockedShot',
#   'X': '0.6919999694824219',
#   'Y': '0.5990000152587891',
#   'xG': '0.007087499834597111',
#   'player': 'Jhon Durán',
#   'h_a': 'a',
#   'player_id': '11366',
#   'situation': 'OpenPlay',
#   'season': '2022',
#   'shotType': 'LeftFoot',
#   'match_id': '18429',
#   'h_team': 'Manchester City',
#   'a_team': 'Aston Villa',
#   'h_goals': '3',
#   'a_goals': '1',
#   'date': '2023-02-12 16:30:00',
#   'player_assisted': None,
#   'lastAction': 'None'},
#  {'id': '509047',
#   'minute': '91',
#   'result': 'ShotOnPost',
#   'X': '0.8730000305175781',
#   'Y': '0.6120000076293945',
#   'xG': '0.06912729889154434',
#   'player': 'Jhon Durán',
#   'h_a': 'a',
#   'player_id': '11366',
#   'situation': 'SetPiece',
#   'season': '2022',
#   'shotType': 'LeftFoot',
#   'match_id': '18429',
#   'h_team': 'Manchester City',
#   'a_team': 'Aston Villa',
#   'h_goals': '3',
#   'a_goals': '1',
#   'date': '2023-02-12 16:30:00',
#   'player_assisted': 'Ollie Watkins',
#   'lastAction': 'HeadPass'},
#  {'id': '509440',
#   'minute': '91',
#   'result': 'SavedShot',
#   'X': '0.865',
#   'Y': '0.26899999618530274',
#   'xG': '0.031135600060224533',
#   'player': 'Jhon Durán',
#   'h_a': 'h',
#   'player_id': '11366',
#   'situation': 'OpenPlay',
#   'season': '2022',
#   'shotType': 'RightFoot',
#   'match_id': '18432',
#   'h_team': 'Aston Villa',
#   'a_team': 'Arsenal',
#   'h_goals': '2',
#   'a_goals': '4',
#   'date': '2023-02-18 12:30:00',
#   'player_assisted': 'Jacob Ramsey',
#   'lastAction': 'Pass'},
#  {'id': '512122',
#   'minute': '94',
#   'result': 'MissedShots',
#   'X': '0.860999984741211',
#   'Y': '0.17299999237060548',
#   'xG': '0.024228699505329132',
#   'player': 'Jhon Durán',
#   'h_a': 'h',
#   'player_id': '11366',
#   'situation': 'OpenPlay',
#   'season': '2022',
#   'shotType': 'LeftFoot',
#   'match_id': '18453',
#   'h_team': 'Aston Villa',
#   'a_team': 'Crystal Palace',
#   'h_goals': '1',
#   'a_goals': '0',
#   'date': '2023-03-04 15:00:00',
#   'player_assisted': 'Douglas Luiz',
#   'lastAction': 'Chipped'},
#  {'id': '514052',
#   'minute': '88',
#   'result': 'BlockedShot',
#   'X': '0.899000015258789',
#   'Y': '0.38799999237060545',
#   'xG': '0.06989339739084244',
#   'player': 'Jhon Durán',
#   'h_a': 'a',
#   'player_id': '11366',
#   'situation': 'OpenPlay',
#   'season': '2022',
#   'shotType': 'RightFoot',
#   'match_id': '18471',
#   'h_team': 'West Ham',
#   'a_team': 'Aston Villa',
#   'h_goals': '1',
#   'a_goals': '1',
#   'date': '2023-03-12 14:00:00',
#   'player_assisted': 'Bertrand Traoré',
#   'lastAction': 'Cross'},
#  {'id': '514054',
#   'minute': '89',
#   'result': 'SavedShot',
#   'X': '0.9369999694824219',
#   'Y': '0.5379999923706055',
#   'xG': '0.529662013053894',
#   'player': 'Jhon Durán',
#   'h_a': 'a',
#   'player_id': '11366',
#   'situation': 'FromCorner',
#   'season': '2022',
#   'shotType': 'LeftFoot',
#   'match_id': '18471',
#   'h_team': 'West Ham',
#   'a_team': 'Aston Villa',
#   'h_goals': '1',
#   'a_goals': '1',
#   'date': '2023-03-12 14:00:00',
#   'player_assisted': 'Ezri Konsa Ngoyo',
#   'lastAction': 'Rebound'},
#  {'id': '514992',
#   'minute': '92',
#   'result': 'MissedShots',
#   'X': '0.8069999694824219',
#   'Y': '0.7730000305175782',
#   'xG': '0.02016190066933632',
#   'player': 'Jhon Durán',
#   'h_a': 'h',
#   'player_id': '11366',
#   'situation': 'OpenPlay',
#   'season': '2022',
#   'shotType': 'LeftFoot',
#   'match_id': '18473',
#   'h_team': 'Aston Villa',
#   'a_team': 'Bournemouth',
#   'h_goals': '3',
#   'a_goals': '0',
#   'date': '2023-03-18 15:00:00',
#   'player_assisted': None,
#   'lastAction': 'Dispossessed'},
#  {'id': '533743',
#   'minute': '74',
#   'result': 'Goal',
#   'X': '0.8619999694824219',
#   'Y': '0.534000015258789',
#   'xG': '0.37734442949295044',
#   'player': 'Jhon Durán',
#   'h_a': 'h',
#   'player_id': '11366',
#   'situation': 'OpenPlay',
#   'season': '2023',
#   'shotType': 'LeftFoot',
#   'match_id': '22292',
#   'h_team': 'Aston Villa',
#   'a_team': 'Everton',
#   'h_goals': '4',
#   'a_goals': '0',
#   'date': '2023-08-20 13:00:00',
#   'player_assisted': None,
#   'lastAction': 'TakeOn'},
#  {'id': '536810',
#   'minute': '75',
#   'result': 'MissedShots',
#   'X': '0.8619999694824219',
#   'Y': '0.7609999847412109',
#   'xG': '0.02423868328332901',
#   'player': 'Jhon Durán',
#   'h_a': 'a',
#   'player_id': '11366',
#   'situation': 'OpenPlay',
#   'season': '2023',
#   'shotType': 'LeftFoot',
#   'match_id': '21933',
#   'h_team': 'Liverpool',
#   'a_team': 'Aston Villa',
#   'h_goals': '3',
#   'a_goals': '0',
#   'date': '2023-09-03 13:00:00',
#   'player_assisted': 'Nicolo Zaniolo',
#   'lastAction': 'Pass'},
#  {'id': '536811',
#   'minute': '76',
#   'result': 'MissedShots',
#   'X': '0.9080000305175782',
#   'Y': '0.7180000305175781',
#   'xG': '0.034951549023389816',
#   'player': 'Jhon Durán',
#   'h_a': 'a',
#   'player_id': '11366',
#   'situation': 'OpenPlay',
#   'season': '2023',
#   'shotType': 'LeftFoot',
#   'match_id': '21933',
#   'h_team': 'Liverpool',
#   'a_team': 'Aston Villa',
#   'h_goals': '3',
#   'a_goals': '0',
#   'date': '2023-09-03 13:00:00',
#   'player_assisted': 'Boubacar Kamara',
#   'lastAction': 'Chipped'},
#  {'id': '537722',
#   'minute': '71',
#   'result': 'SavedShot',
#   'X': '0.8080000305175781',
#   'Y': '0.49400001525878906',
#   'xG': '0.0373753122985363',
#   'player': 'Jhon Durán',
#   'h_a': 'h',
#   'player_id': '11366',
#   'situation': 'OpenPlay',
#   'season': '2023',
#   'shotType': 'LeftFoot',
#   'match_id': '21938',
#   'h_team': 'Aston Villa',
#   'a_team': 'Crystal Palace',
#   'h_goals': '3',
#   'a_goals': '1',
#   'date': '2023-09-16 14:00:00',
#   'player_assisted': 'Douglas Luiz',
#   'lastAction': 'HeadPass'},
#  {'id': '537728',
#   'minute': '86',
#   'result': 'Goal',
#   'X': '0.8540000152587891',
#   'Y': '0.445',
#   'xG': '0.052523061633110046',
#   'player': 'Jhon Durán',
#   'h_a': 'h',
#   'player_id': '11366',
#   'situation': 'OpenPlay',
#   'season': '2023',
#   'shotType': 'LeftFoot',
#   'match_id': '21938',
#   'h_team': 'Aston Villa',
#   'a_team': 'Crystal Palace',
#   'h_goals': '3',
#   'a_goals': '1',
#   'date': '2023-09-16 14:00:00',
#   'player_assisted': 'Lucas Digne',
#   'lastAction': 'Cross'},
#  {'id': '550317',
#   'minute': '96',
#   'result': 'MissedShots',
#   'X': '0.7780000305175782',
#   'Y': '0.18600000381469728',
#   'xG': '0.011197090148925781',
#   'player': 'Jhon Durán',
#   'h_a': 'a',
#   'player_id': '11366',
#   'situation': 'OpenPlay',
#   'season': '2023',
#   'shotType': 'LeftFoot',
#   'match_id': '22024',
#   'h_team': 'Tottenham',
#   'a_team': 'Aston Villa',
#   'h_goals': '1',
#   'a_goals': '2',
#   'date': '2023-11-26 14:00:00',
#   'player_assisted': 'Leon Bailey',
#   'lastAction': 'HeadPass'},
#  {'id': '551584',
#   'minute': '71',
#   'result': 'BlockedShot',
#   'X': '0.8090000152587891',
#   'Y': '0.5120000076293946',
#   'xG': '0.058037202805280685',
#   'player': 'Jhon Durán',
#   'h_a': 'a',
#   'player_id': '11366',
#   'situation': 'OpenPlay',
#   'season': '2023',
#   'shotType': 'RightFoot',
#   'match_id': '22025',
#   'h_team': 'Bournemouth',
#   'a_team': 'Aston Villa',
#   'h_goals': '2',
#   'a_goals': '2',
#   'date': '2023-12-03 14:00:00',
#   'player_assisted': 'Ollie Watkins',
#   'lastAction': 'Pass'},
#  {'id': '554739',
#   'minute': '74',
#   'result': 'MissedShots',
#   'X': '0.7780000305175782',
#   'Y': '0.6909999847412109',
#   'xG': '0.020944802090525627',
#   'player': 'Jhon Durán',
#   'h_a': 'a',
#   'player_id': '11366',
#   'situation': 'OpenPlay',
#   'season': '2023',
#   'shotType': 'RightFoot',
#   'match_id': '22057',
#   'h_team': 'Brentford',
#   'a_team': 'Aston Villa',
#   'h_goals': '1',
#   'a_goals': '2',
#   'date': '2023-12-17 14:00:00',
#   'player_assisted': 'Jacob Ramsey',
#   'lastAction': 'Pass'},
#  {'id': '558440',
#   'minute': '76',
#   'result': 'SavedShot',
#   'X': '0.904000015258789',
#   'Y': '0.5459999847412109',
#   'xG': '0.05104731395840645',
#   'player': 'Jhon Durán',
#   'h_a': 'a',
#   'player_id': '11366',
#   'situation': 'OpenPlay',
#   'season': '2023',
#   'shotType': 'Head',
#   'match_id': '22098',
#   'h_team': 'Everton',
#   'a_team': 'Aston Villa',
#   'h_goals': '0',
#   'a_goals': '0',
#   'date': '2024-01-14 14:00:00',
#   'player_assisted': None,
#   'lastAction': 'Aerial'},
#  {'id': '558439',
#   'minute': '76',
#   'result': 'MissedShots',
#   'X': '0.9119999694824219',
#   'Y': '0.524000015258789',
#   'xG': '0.06123877689242363',
#   'player': 'Jhon Durán',
#   'h_a': 'a',
#   'player_id': '11366',
#   'situation': 'OpenPlay',
#   'season': '2023',
#   'shotType': 'OtherBodyPart',
#   'match_id': '22098',
#   'h_team': 'Everton',
#   'a_team': 'Aston Villa',
#   'h_goals': '0',
#   'a_goals': '0',
#   'date': '2024-01-14 14:00:00',
#   'player_assisted': None,
#   'lastAction': 'Aerial'},
#  {'id': '558445',
#   'minute': '86',
#   'result': 'MissedShots',
#   'X': '0.9640000152587891',
#   'Y': '0.43099998474121093',
#   'xG': '0.44258418679237366',
#   'player': 'Jhon Durán',
#   'h_a': 'a',
#   'player_id': '11366',
#   'situation': 'OpenPlay',
#   'season': '2023',
#   'shotType': 'LeftFoot',
#   'match_id': '22098',
#   'h_team': 'Everton',
#   'a_team': 'Aston Villa',
#   'h_goals': '0',
#   'a_goals': '0',
#   'date': '2024-01-14 14:00:00',
#   'player_assisted': 'Matthew Cash',
#   'lastAction': 'Cross'},
#  {'id': '558446',
#   'minute': '93',
#   'result': 'MissedShots',
#   'X': '0.8959999847412109',
#   'Y': '0.4620000076293945',
#   'xG': '0.07033639401197433',
#   'player': 'Jhon Durán',
#   'h_a': 'a',
#   'player_id': '11366',
#   'situation': 'OpenPlay',
#   'season': '2023',
#   'shotType': 'Head',
#   'match_id': '22098',
#   'h_team': 'Everton',
#   'a_team': 'Aston Villa',
#   'h_goals': '0',
#   'a_goals': '0',
#   'date': '2024-01-14 14:00:00',
#   'player_assisted': 'Álex Moreno',
#   'lastAction': 'Cross'},
#  {'id': '570947',
#   'minute': '73',
#   'result': 'BlockedShot',
#   'X': '0.8969999694824219',
#   'Y': '0.6940000152587891',
#   'xG': '0.061118487268686295',
#   'player': 'Jhon Durán',
#   'h_a': 'h',
#   'player_id': '11366',
#   'situation': 'OpenPlay',
#   'season': '2023',
#   'shotType': 'LeftFoot',
#   'match_id': '22186',
#   'h_team': 'Aston Villa',
#   'a_team': 'Wolverhampton Wanderers',
#   'h_goals': '2',
#   'a_goals': '0',
#   'date': '2024-03-30 17:30:00',
#   'player_assisted': 'Lucas Digne',
#   'lastAction': 'Pass'},
#  {'id': '571919',
#   'minute': '19',
#   'result': 'Goal',
#   'X': '0.9369999694824219',
#   'Y': '0.6980000305175781',
#   'xG': '0.3411291539669037',
#   'player': 'Jhon Durán',
#   'h_a': 'a',
#   'player_id': '11366',
#   'situation': 'OpenPlay',
#   'season': '2023',
#   'shotType': 'LeftFoot',
#   'match_id': '22204',
#   'h_team': 'Manchester City',
#   'a_team': 'Aston Villa',
#   'h_goals': '4',
#   'a_goals': '1',
#   'date': '2024-04-03 19:15:00',
#   'player_assisted': 'Morgan Rogers',
#   'lastAction': 'Pass'},
#  {'id': '577034',
#   'minute': '98',
#   'result': 'MissedShots',
#   'X': '0.94',
#   'Y': '0.5540000152587891',
#   'xG': '0.0539235882461071',
#   'player': 'Jhon Durán',
#   'h_a': 'h',
#   'player_id': '11366',
#   'situation': 'FromCorner',
#   'season': '2023',
#   'shotType': 'Head',
#   'match_id': '22236',
#   'h_team': 'Aston Villa',
#   'a_team': 'Chelsea',
#   'h_goals': '2',
#   'a_goals': '2',
#   'date': '2024-04-27 19:00:00',
#   'player_assisted': 'Lucas Digne',
#   'lastAction': 'Aerial'},
#  {'id': '580925',
#   'minute': '83',
#   'result': 'BlockedShot',
#   'X': '0.8809999847412109',
#   'Y': '0.46',
#   'xG': '0.09937392920255661',
#   'player': 'Jhon Durán',
#   'h_a': 'h',
#   'player_id': '11366',
#   'situation': 'OpenPlay',
#   'season': '2023',
#   'shotType': 'LeftFoot',
#   'match_id': '22256',
#   'h_team': 'Aston Villa',
#   'a_team': 'Liverpool',
#   'h_goals': '3',
#   'a_goals': '3',
#   'date': '2024-05-13 19:00:00',
#   'player_assisted': 'Leon Bailey',
#   'lastAction': 'Throughball'},
#  {'id': '580926',
#   'minute': '84',
#   'result': 'Goal',
#   'X': '0.8080000305175781',
#   'Y': '0.48200000762939454',
#   'xG': '0.05676691234111786',
#   'player': 'Jhon Durán',
#   'h_a': 'h',
#   'player_id': '11366',
#   'situation': 'OpenPlay',
#   'season': '2023',
#   'shotType': 'LeftFoot',
#   'match_id': '22256',
#   'h_team': 'Aston Villa',
#   'a_team': 'Liverpool',
#   'h_goals': '3',
#   'a_goals': '3',
#   'date': '2024-05-13 19:00:00',
#   'player_assisted': 'Calum Chambers',
#   'lastAction': 'BallRecovery'},
#  {'id': '580928',
#   'minute': '87',
#   'result': 'Goal',
#   'X': '0.8169999694824219',
#   'Y': '0.4859999847412109',
#   'xG': '0.05246451124548912',
#   'player': 'Jhon Durán',
#   'h_a': 'h',
#   'player_id': '11366',
#   'situation': 'OpenPlay',
#   'season': '2023',
#   'shotType': 'LeftFoot',
#   'match_id': '22256',
#   'h_team': 'Aston Villa',
#   'a_team': 'Liverpool',
#   'h_goals': '3',
#   'a_goals': '3',
#   'date': '2024-05-13 19:00:00',
#   'player_assisted': 'Moussa Diaby',
#   'lastAction': 'Pass'},
#  {'id': '582055',
#   'minute': '18',
#   'result': 'MissedShots',
#   'X': '0.7230000305175781',
#   'Y': '0.42700000762939455',
#   'xG': '0.014124225825071335',
#   'player': 'Jhon Durán',
#   'h_a': 'a',
#   'player_id': '11366',
#   'situation': 'OpenPlay',
#   'season': '2023',
#   'shotType': 'LeftFoot',
#   'match_id': '22270',
#   'h_team': 'Crystal Palace',
#   'a_team': 'Aston Villa',
#   'h_goals': '5',
#   'a_goals': '0',
#   'date': '2024-05-19 15:00:00',
#   'player_assisted': None,
#   'lastAction': 'None'},
#  {'id': '582063',
#   'minute': '49',
#   'result': 'MissedShots',
#   'X': '0.895',
#   'Y': '0.6170000076293946',
#   'xG': '0.02801802009344101',
#   'player': 'Jhon Durán',
#   'h_a': 'a',
#   'player_id': '11366',
#   'situation': 'OpenPlay',
#   'season': '2023',
#   'shotType': 'Head',
#   'match_id': '22270',
#   'h_team': 'Crystal Palace',
#   'a_team': 'Aston Villa',
#   'h_goals': '5',
#   'a_goals': '0',
#   'date': '2024-05-19 15:00:00',
#   'player_assisted': 'Lucas Digne',
#   'lastAction': 'Aerial'},
#  {'id': '584870',
#   'minute': '65',
#   'result': 'MissedShots',
#   'X': '0.8669999694824219',
#   'Y': '0.6840000152587891',
#   'xG': '0.3044654428958893',
#   'player': 'Jhon Durán',
#   'h_a': 'a',
#   'player_id': '11366',
#   'situation': 'OpenPlay',
#   'season': '2024',
#   'shotType': 'LeftFoot',
#   'match_id': '26608',
#   'h_team': 'West Ham',
#   'a_team': 'Aston Villa',
#   'h_goals': '1',
#   'a_goals': '2',
#   'date': '2024-08-17 16:30:00',
#   'player_assisted': 'Lucas Digne',
#   'lastAction': 'Throughball'},
#  {'id': '584872',
#   'minute': '78',
#   'result': 'Goal',
#   'X': '0.8809999847412109',
#   'Y': '0.53',
#   'xG': '0.3958303928375244',
#   'player': 'Jhon Durán',
#   'h_a': 'a',
#   'player_id': '11366',
#   'situation': 'OpenPlay',
#   'season': '2024',
#   'shotType': 'LeftFoot',
#   'match_id': '26608',
#   'h_team': 'West Ham',
#   'a_team': 'Aston Villa',
#   'h_goals': '1',
#   'a_goals': '2',
#   'date': '2024-08-17 16:30:00',
#   'player_assisted': 'Jacob Ramsey',
#   'lastAction': 'Pass'},
#  {'id': '586316',
#   'minute': '86',
#   'result': 'BlockedShot',
#   'X': '0.924000015258789',
#   'Y': '0.5940000152587891',
#   'xG': '0.06511788815259933',
#   'player': 'Jhon Durán',
#   'h_a': 'h',
#   'player_id': '11366',
#   'situation': 'OpenPlay',
#   'season': '2024',
#   'shotType': 'LeftFoot',
#   'match_id': '26618',
#   'h_team': 'Aston Villa',
#   'a_team': 'Arsenal',
#   'h_goals': '0',
#   'a_goals': '2',
#   'date': '2024-08-24 16:30:00',
#   'player_assisted': 'Ian Maatsen',
#   'lastAction': 'Cross'},
#  {'id': '589246',
#   'minute': '62',
#   'result': 'Goal',
#   'X': '0.9290000152587891',
#   'Y': '0.5429999923706055',
#   'xG': '0.3750728666782379',
#   'player': 'Jhon Durán',
#   'h_a': 'a',
#   'player_id': '11366',
#   'situation': 'OpenPlay',
#   'season': '2024',
#   'shotType': 'Head',
#   'match_id': '26626',
#   'h_team': 'Leicester',
#   'a_team': 'Aston Villa',
#   'h_goals': '1',
#   'a_goals': '2',
#   'date': '2024-08-31 14:00:00',
#   'player_assisted': 'Lucas Digne',
#   'lastAction': 'Cross'},
#  {'id': '589250',
#   'minute': '84',
#   'result': 'SavedShot',
#   'X': '0.8669999694824219',
#   'Y': '0.485',
#   'xG': '0.12262330204248428',
#   'player': 'Jhon Durán',
#   'h_a': 'a',
#   'player_id': '11366',
#   'situation': 'OpenPlay',
#   'season': '2024',
#   'shotType': 'LeftFoot',
#   'match_id': '26626',
#   'h_team': 'Leicester',
#   'a_team': 'Aston Villa',
#   'h_goals': '1',
#   'a_goals': '2',
#   'date': '2024-08-31 14:00:00',
#   'player_assisted': 'Ross Barkley',
#   'lastAction': 'Pass'},
#  {'id': '590999',
#   'minute': '75',
#   'result': 'Goal',
#   'X': '0.7280000305175781',
#   'Y': '0.6359999847412109',
#   'xG': '0.017542922869324684',
#   'player': 'Jhon Durán',
#   'h_a': 'h',
#   'player_id': '11366',
#   'situation': 'OpenPlay',
#   'season': '2024',
#   'shotType': 'LeftFoot',
#   'match_id': '26638',
#   'h_team': 'Aston Villa',
#   'a_team': 'Everton',
#   'h_goals': '3',
#   'a_goals': '2',
#   'date': '2024-09-14 16:30:00',
#   'player_assisted': 'Ross Barkley',
#   'lastAction': 'Pass'},
#  {'id': '591002',
#   'minute': '85',
#   'result': 'MissedShots',
#   'X': '0.925',
#   'Y': '0.6020000076293945',
#   'xG': '0.1135372444987297',
#   'player': 'Jhon Durán',
#   'h_a': 'h',
#   'player_id': '11366',
#   'situation': 'OpenPlay',
#   'season': '2024',
#   'shotType': 'LeftFoot',
#   'match_id': '26638',
#   'h_team': 'Aston Villa',
#   'a_team': 'Everton',
#   'h_goals': '3',
#   'a_goals': '2',
#   'date': '2024-09-14 16:30:00',
#   'player_assisted': 'Ian Maatsen',
#   'lastAction': 'Chipped'},
#  {'id': '591004',
#   'minute': '94',
#   'result': 'MissedShots',
#   'X': '0.9269999694824219',
#   'Y': '0.515',
#   'xG': '0.13121600449085236',
#   'player': 'Jhon Durán',
#   'h_a': 'h',
#   'player_id': '11366',
#   'situation': 'SetPiece',
#   'season': '2024',
#   'shotType': 'Head',
#   'match_id': '26638',
#   'h_team': 'Aston Villa',
#   'a_team': 'Everton',
#   'h_goals': '3',
#   'a_goals': '2',
#   'date': '2024-09-14 16:30:00',
#   'player_assisted': 'Ian Maatsen',
#   'lastAction': 'Cross'}]

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#         id minute       result                   X                    Y  \
# 0   509044     78  BlockedShot  0.6919999694824219   0.5990000152587891
# 1   509047     91   ShotOnPost  0.8730000305175781   0.6120000076293945
# 2   509440     91    SavedShot               0.865  0.26899999618530274
# 3   512122     94  MissedShots   0.860999984741211  0.17299999237060548
# 4   514052     88  BlockedShot   0.899000015258789  0.38799999237060545
# 5   514054     89    SavedShot  0.9369999694824219   0.5379999923706055
# 6   514992     92  MissedShots  0.8069999694824219   0.7730000305175782
# 7   533743     74         Goal  0.8619999694824219    0.534000015258789
# 8   536810     75  MissedShots  0.8619999694824219   0.7609999847412109
# 9   536811     76  MissedShots  0.9080000305175782   0.7180000305175781
# 10  537722     71    SavedShot  0.8080000305175781  0.49400001525878906
# 11  537728     86         Goal  0.8540000152587891                0.445
# 12  550317     96  MissedShots  0.7780000305175782  0.18600000381469728
# 13  551584     71  BlockedShot  0.8090000152587891   0.5120000076293946
# 14  554739     74  MissedShots  0.7780000305175782   0.6909999847412109
# 15  558440     76    SavedShot   0.904000015258789   0.5459999847412109
# 16  558439     76  MissedShots  0.9119999694824219    0.524000015258789
# 17  558445     86  MissedShots  0.9640000152587891  0.43099998474121093
# 18  558446     93  MissedShots  0.8959999847412109   0.4620000076293945
# 19  570947     73  BlockedShot  0.8969999694824219   0.6940000152587891
# 20  571919     19         Goal  0.9369999694824219   0.6980000305175781
# 21  577034     98  MissedShots                0.94   0.5540000152587891
# 22  580925     83  BlockedShot  0.8809999847412109                 0.46
# 23  580926     84         Goal  0.8080000305175781  0.48200000762939454
# 24  580928     87         Goal  0.8169999694824219   0.4859999847412109
# 25  582055     18  MissedShots  0.7230000305175781  0.42700000762939455
# 26  582063     49  MissedShots               0.895   0.6170000076293946
# 27  584870     65  MissedShots  0.8669999694824219   0.6840000152587891
# 28  584872     78         Goal  0.8809999847412109                 0.53
# 29  586316     86  BlockedShot   0.924000015258789   0.5940000152587891
# 30  589246     62         Goal  0.9290000152587891   0.5429999923706055
# 31  589250     84    SavedShot  0.8669999694824219                0.485
# 32  590999     75         Goal  0.7280000305175781   0.6359999847412109
# 33  591002     85  MissedShots               0.925   0.6020000076293945
# 34  591004     94  MissedShots  0.9269999694824219                0.515
#
#                       xG      player h_a player_id   situation season  \
# 0   0.007087499834597111  Jhon Durán   a     11366    OpenPlay   2022
# 1    0.06912729889154434  Jhon Durán   a     11366    SetPiece   2022
# 2   0.031135600060224533  Jhon Durán   h     11366    OpenPlay   2022
# 3   0.024228699505329132  Jhon Durán   h     11366    OpenPlay   2022
# 4    0.06989339739084244  Jhon Durán   a     11366    OpenPlay   2022
